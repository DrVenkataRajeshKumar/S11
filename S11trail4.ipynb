# %% [markdown]
# <a href="https://colab.research.google.com/github/DrVenkataRajeshKumar/S11/blob/master/S11trail4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from torchvision import datasets
train = datasets.CIFAR10('./data', train=True, download=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
# !pip install -U git+https://github.com/albu/albumentations > /dev/null && echo "All libraries are successfully installed!"
# Out:
#   Running command git clone -q https://github.com/albu/albumentations /tmp/pip-req-build-wrohhz41
# All libraries are successfully installed!

# %%
from tqdm import tqdm_notebook
from PIL import Image
import numpy as np
n = 0
s = np.zeros(3)
sq = np.zeros(3)
for data, l in tqdm_notebook(train):
  x = np.array(data)/255
  s += x.sum(axis=(0,1))
  sq += np.sum(np.square(x), axis=(0,1))
  n += x.shape[0]*x.shape[1]

mu = s/n
std = np.sqrt((sq/n - np.square(mu)))
print(mu, sq/n, std, n)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))
# [0.49139968 0.48215841 0.44653091] [0.30249857 0.29176174 0.26781806] [0.24703223 0.24348513 0.26158784] 51200000

# %%
import sys
sys.path.append('/content/drive/My Drive/EVA4')

# %%
import numpy as np
from eva4albumentations import AlbumentationTransforms
import albumentations as A


channel_means = (0.49139968, 0.48215841, 0.44653091)
channel_stdevs = (0.24703223, 0.24348513, 0.26158784)
# Train Phase transformations
train_transforms = AlbumentationTransforms([
                                       A.PadIfNeeded(40,40),
                                       A.RandomCrop(32,32),
                                       A.HorizontalFlip(),
                                       A.Normalize(mean=channel_means, std=channel_stdevs),
                                       A.Cutout(8)
                                       ])

fillmeans = (np.array(channel_means)).astype(np.uint8)



# Test Phase transformations
test_transforms = AlbumentationTransforms([A.Normalize(mean=channel_means, std=channel_stdevs)])

# %%
from torchvision import datasets
train = datasets.CIFAR10('./data', train=True, download=True, transform=train_transforms)
test = datasets.CIFAR10('./data', train=False, download=True, transform=test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import eva4dataloaders

dataloader = eva4dataloaders.DataLoader()

# train dataloader
train_loader = dataloader.load(train)

# test dataloader
test_loader = dataloader.load(test)

# %%
import numpy as np
dataiter = iter(train_loader)
images, labels = dataiter.next()
i = images[90].numpy()
print(np.max(i), np.min(i))
# Out:
# 1.5952917 -1.8513899

# %%
from __future__ import print_function

def unnormalize(img):
  img = img.numpy().astype(dtype=np.float32)
  
  for i in range(img.shape[0]):
    img[i] = (img[i]*channel_stdevs[i])+channel_means[i]
  
  return np.transpose(img, (1,2,0))

# %matplotlib inline
import matplotlib.pyplot as plt
dataiter = iter(train_loader)
images, labels = dataiter.next()

print(images.shape)
print(labels.shape)

num_classes = 10
# display 10 images from each category. 
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
r, c = 10, 11
n = 5
fig = plt.figure(figsize=(10,10))
fig.subplots_adjust(hspace=0.01, wspace=0.01)
for i in range(num_classes):
    idx = np.random.choice(np.where(labels[:]==i)[0], n)
    ax = plt.subplot(r, c, i*c+1)
    ax.text(-1.5, 0.5, class_names[i], fontsize=14)
    plt.axis('off')
    for j in range(1, n+1):
      plt.subplot(r, c, i*c+j+1)
      plt.imshow(unnormalize(images[idx[j-1]]), interpolation='none')
      plt.axis('off')
plt.show()
# Out:
# torch.Size([512, 3, 32, 32])
# torch.Size([512])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import a11
import torch

model = a11.Quiz11()
use_cuda = torch.cuda.is_available()
model.device = torch.device("cuda" if use_cuda else "cpu")
model.to(model.device)
model.summary((3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#               ReLU-2           [-1, 64, 32, 32]               0
#        BatchNorm2d-3           [-1, 64, 32, 32]             128
#             Conv2d-4          [-1, 128, 32, 32]          73,728
#          MaxPool2d-5          [-1, 128, 16, 16]               0
#               ReLU-6          [-1, 128, 16, 16]               0
#        BatchNorm2d-7          [-1, 128, 16, 16]             256
#             Conv2d-8          [-1, 128, 16, 16]         147,456
#               ReLU-9          [-1, 128, 16, 16]               0
#       BatchNorm2d-10          [-1, 128, 16, 16]             256
#            Conv2d-11          [-1, 128, 16, 16]         147,456
#              ReLU-12          [-1, 128, 16, 16]               0
#       BatchNorm2d-13          [-1, 128, 16, 16]             256
#            Conv2d-14          [-1, 256, 16, 16]         294,912
#         MaxPool2d-15            [-1, 256, 8, 8]               0
#              ReLU-16            [-1, 256, 8, 8]               0
#       BatchNorm2d-17            [-1, 256, 8, 8]             512
#            Conv2d-18            [-1, 512, 8, 8]       1,179,648
#         MaxPool2d-19            [-1, 512, 4, 4]               0
#              ReLU-20            [-1, 512, 4, 4]               0
#       BatchNorm2d-21            [-1, 512, 4, 4]           1,024
#            Conv2d-22            [-1, 512, 4, 4]       2,359,296
#              ReLU-23            [-1, 512, 4, 4]               0
#       BatchNorm2d-24            [-1, 512, 4, 4]           1,024
#            Conv2d-25            [-1, 512, 4, 4]       2,359,296
#              ReLU-26            [-1, 512, 4, 4]               0
#       BatchNorm2d-27            [-1, 512, 4, 4]           1,024
#         MaxPool2d-28            [-1, 512, 1, 1]               0
#            Conv2d-29             [-1, 10, 1, 1]           5,130
# ================================================================
# Total params: 6,573,130
# Trainable params: 6,573,130
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 6.44
# Params size (MB): 25.07
# Estimated Total Size (MB): 31.53
# ----------------------------------------------------------------

# %%
import LR_Range_Test
from LR_Range_Test import LR_test
import torch.nn as nn
max_lr = 0.01
base_lr = 0.001
epoch = 20
criterion = nn.NLLLoss()

LR_test(max_lr, base_lr, model.device, epoch, model, criterion, train_loader, momemtum  =0.9, weight_decay=0.05, plot= True)
# Out:
# epoch = 1 Lr = 0.001  Loss=1.3700740337371826 Batch_id=97 Accuracy=39.36: 100%|██████████| 98/98 [00:30<00:00,  3.18it/s]
# epoch = 2 Lr = 0.0014500000000000001  Loss=1.33413827419281 Batch_id=97 Accuracy=40.98: 100%|██████████| 98/98 [00:30<00:00,  3.21it/s]
# epoch = 3 Lr = 0.0019000000000000002  Loss=1.3853635787963867 Batch_id=97 Accuracy=41.52: 100%|██████████| 98/98 [00:30<00:00,  3.17it/s]
# epoch = 4 Lr = 0.00235  Loss=1.2590430974960327 Batch_id=97 Accuracy=42.12: 100%|██████████| 98/98 [00:30<00:00,  3.20it/s]
# epoch = 5 Lr = 0.0028  Loss=1.3263170719146729 Batch_id=97 Accuracy=42.21: 100%|██████████| 98/98 [00:30<00:00,  3.21it/s]
# epoch = 6 Lr = 0.00325  Loss=1.2275669574737549 Batch_id=97 Accuracy=42.04: 100%|██████████| 98/98 [00:30<00:00,  3.19it/s]
# epoch = 7 Lr = 0.0036999999999999997  Loss=1.3914438486099243 Batch_id=97 Accuracy=42.34: 100%|██████████| 98/98 [00:30<00:00,  3.21it/s]
# epoch = 8 Lr = 0.00415  Loss=1.1996347904205322 Batch_id=97 Accuracy=42.17: 100%|██████████| 98/98 [00:30<00:00,  3.25it/s]
# epoch = 9 Lr = 0.0046  Loss=1.309154748916626 Batch_id=97 Accuracy=40.76: 100%|██████████| 98/98 [00:30<00:00,  3.26it/s]
# epoch = 10 Lr = 0.00505  Loss=1.3952255249023438 Batch_id=97 Accuracy=41.08: 100%|██████████| 98/98 [00:29<00:00,  3.31it/s]
# epoch = 11 Lr = 0.0055  Loss=1.3393601179122925 Batch_id=97 Accuracy=39.11: 100%|██████████| 98/98 [00:29<00:00,  3.27it/s]
# epoch = 12 Lr = 0.0059499999999999996  Loss=1.3820067644119263 Batch_id=97 Accuracy=40.41: 100%|██████████| 98/98 [00:29<00:00,  3.35it/s]
# epoch = 13 Lr = 0.0063999999999999994  Loss=1.4062753915786743 Batch_id=97 Accuracy=37.65: 100%|██████████| 98/98 [00:29<00:00,  3.34it/s]
# epoch = 14 Lr = 0.006849999999999999  Loss=1.335279941558838 Batch_id=97 Accuracy=38.15: 100%|██████████| 98/98 [00:29<00:00,  3.29it/s]
# epoch = 15 Lr = 0.007299999999999999  Loss=1.4320367574691772 Batch_id=97 Accuracy=35.55: 100%|██████████| 98/98 [00:29<00:00,  3.35it/s]
# epoch = 16 Lr = 0.007749999999999999  Loss=1.5851808786392212 Batch_id=97 Accuracy=34.68: 100%|██████████| 98/98 [00:29<00:00,  3.32it/s]
# epoch = 17 Lr = 0.008199999999999999  Loss=1.5067975521087646 Batch_id=97 Accuracy=36.44: 100%|██████████| 98/98 [00:29<00:00,  3.32it/s]
# epoch = 18 Lr = 0.00865  Loss=1.3506911993026733 Batch_id=97 Accuracy=36.08: 100%|██████████| 98/98 [00:28<00:00,  3.40it/s]
# epoch = 19 Lr = 0.0091  Loss=1.5165733098983765 Batch_id=97 Accuracy=33.02: 100%|██████████| 98/98 [00:29<00:00,  3.35it/s]
# epoch = 20 Lr = 0.009550000000000001  Loss=1.5525641441345215 Batch_id=97 Accuracy=31.62: 100%|██████████| 98/98 [00:29<00:00,  3.35it/s]

# %%
from lrfinder import LRFinder
import torch.optim as optim
import torch.nn as nn
L1lambda = 0
L2lambda = 1e-4
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-7, momentum=0.9, nesterov=True, weight_decay=L2lambda)
lr_finder = LRFinder(model, optimizer, criterion, device=model.device)
lr_finder.range_test(train_loader, end_lr=100, num_iter=100)
lr_finder.plot() # to inspect the loss-learning rate graph
lr_finder.reset() # to reset the model and optimizer to their initial state
# Out:
# WARNING:lrfinder:To enable mixed precision training, please install `apex`. Or you can re-install this package by the following command:
#   pip install torch-lr-finder -v --global-option="amp"
# HBox(children=(IntProgress(value=0), HTML(value='')))
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
device = model.device


EPOCHS = 25
#scheduler = StepLR(optimizer, step_size=5, gamma=0.5)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, nesterov=True, weight_decay=L2lambda)
scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer,
                 max_lr=0.03,
                 total_steps=25,
                 epochs=25,
                 pct_start=0.2,
                 cycle_momentum=False,
                 base_momentum=0.85,
                 max_momentum=0.95,
                 div_factor=10.,
                 final_div_factor=1e4,
                 last_epoch=-1)



model.gotrain(optimizer, train_loader, test_loader, EPOCHS, "/content/drive/My Drive", scheduler, False, L1lambda)
# Out:
# HBox(children=(IntProgress(value=0, description='Epochs', max=25, style=ProgressStyle(description_width='initi…
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (100000.000000 --> 1.181484).  Saving model ...
# Epoch: 1, Train set: Average loss: 0.0032, Accuracy: 44.22%; Test set: Average loss: 1.1815, Accuracy: 57.63%
# Learning Rate = 0.003000
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (1.181484 --> 1.004753).  Saving model ...
# Epoch: 2, Train set: Average loss: 0.0027, Accuracy: 53.81%; Test set: Average loss: 1.0048, Accuracy: 64.84%
# Learning Rate = 0.006954
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (1.004753 --> 0.931911).  Saving model ...
# Epoch: 3, Train set: Average loss: 0.0031, Accuracy: 53.38%; Test set: Average loss: 0.9319, Accuracy: 67.58%
# Learning Rate = 0.016500
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.931911 --> 0.782315).  Saving model ...
# Epoch: 4, Train set: Average loss: 0.0024, Accuracy: 60.69%; Test set: Average loss: 0.7823, Accuracy: 72.84%
# Learning Rate = 0.026046
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Epoch: 5, Train set: Average loss: 0.0019, Accuracy: 67.58%; Test set: Average loss: 0.8416, Accuracy: 72.18%
# Learning Rate = 0.030000
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.782315 --> 0.577768).  Saving model ...
# Epoch: 6, Train set: Average loss: 0.0015, Accuracy: 73.04%; Test set: Average loss: 0.5778, Accuracy: 80.20%
# Learning Rate = 0.029815
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Epoch: 7, Train set: Average loss: 0.0014, Accuracy: 75.76%; Test set: Average loss: 0.7169, Accuracy: 78.32%
# Learning Rate = 0.029266
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.577768 --> 0.526212).  Saving model ...
# Epoch: 8, Train set: Average loss: 0.0013, Accuracy: 77.97%; Test set: Average loss: 0.5262, Accuracy: 82.66%
# Learning Rate = 0.028365
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.526212 --> 0.517336).  Saving model ...
# Epoch: 9, Train set: Average loss: 0.0011, Accuracy: 79.98%; Test set: Average loss: 0.5173, Accuracy: 83.08%
# Learning Rate = 0.027135
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.517336 --> 0.485778).  Saving model ...
# Epoch: 10, Train set: Average loss: 0.0010, Accuracy: 81.36%; Test set: Average loss: 0.4858, Accuracy: 84.63%
# Learning Rate = 0.025607
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.485778 --> 0.455414).  Saving model ...
# Epoch: 11, Train set: Average loss: 0.0010, Accuracy: 82.79%; Test set: Average loss: 0.4554, Accuracy: 84.98%
# Learning Rate = 0.023817
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.455414 --> 0.410338).  Saving model ...
# Epoch: 12, Train set: Average loss: 0.0009, Accuracy: 83.74%; Test set: Average loss: 0.4103, Accuracy: 86.72%
# Learning Rate = 0.021810
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.410338 --> 0.399492).  Saving model ...
# Epoch: 13, Train set: Average loss: 0.0008, Accuracy: 85.09%; Test set: Average loss: 0.3995, Accuracy: 86.91%
# Learning Rate = 0.019635
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.399492 --> 0.355307).  Saving model ...
# Epoch: 14, Train set: Average loss: 0.0008, Accuracy: 85.94%; Test set: Average loss: 0.3553, Accuracy: 88.37%
# Learning Rate = 0.017347
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Epoch: 15, Train set: Average loss: 0.0007, Accuracy: 86.89%; Test set: Average loss: 0.3601, Accuracy: 88.26%
# Learning Rate = 0.015000
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.355307 --> 0.338329).  Saving model ...
# Epoch: 16, Train set: Average loss: 0.0007, Accuracy: 87.84%; Test set: Average loss: 0.3383, Accuracy: 89.14%
# Learning Rate = 0.012654
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.338329 --> 0.334180).  Saving model ...
# Epoch: 17, Train set: Average loss: 0.0006, Accuracy: 88.82%; Test set: Average loss: 0.3342, Accuracy: 89.02%
# Learning Rate = 0.010365
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.334180 --> 0.310081).  Saving model ...
# Epoch: 18, Train set: Average loss: 0.0006, Accuracy: 88.97%; Test set: Average loss: 0.3101, Accuracy: 89.58%
# Learning Rate = 0.008190
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.310081 --> 0.308701).  Saving model ...
# Epoch: 19, Train set: Average loss: 0.0006, Accuracy: 89.75%; Test set: Average loss: 0.3087, Accuracy: 89.88%
# Learning Rate = 0.006183
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.308701 --> 0.297294).  Saving model ...
# Epoch: 20, Train set: Average loss: 0.0005, Accuracy: 90.50%; Test set: Average loss: 0.2973, Accuracy: 90.25%
# Learning Rate = 0.004394
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.297294 --> 0.287698).  Saving model ...
# Epoch: 21, Train set: Average loss: 0.0005, Accuracy: 90.86%; Test set: Average loss: 0.2877, Accuracy: 90.60%
# Learning Rate = 0.002865
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.287698 --> 0.287408).  Saving model ...
# Epoch: 22, Train set: Average loss: 0.0005, Accuracy: 90.96%; Test set: Average loss: 0.2874, Accuracy: 90.49%
# Learning Rate = 0.001635
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Epoch: 23, Train set: Average loss: 0.0005, Accuracy: 91.62%; Test set: Average loss: 0.2892, Accuracy: 90.60%
# Learning Rate = 0.000734
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.287408 --> 0.286503).  Saving model ...
# Epoch: 24, Train set: Average loss: 0.0005, Accuracy: 91.62%; Test set: Average loss: 0.2865, Accuracy: 90.75%
# Learning Rate = 0.000185
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.286503 --> 0.286449).  Saving model ...
# Epoch: 25, Train set: Average loss: 0.0005, Accuracy: 91.75%; Test set: Average loss: 0.2864, Accuracy: 90.70%
# Learning Rate = 0.000000

# %%
fig, ax1 = plt.subplots()
t = np.arange(1, 26)
color = 'tab:red'
ax1.set_xlabel('epoch (s)')
ax1.set_ylabel('accuracy', color=color)
testline, = ax1.plot(t, model.stats().test_acc, color=color)
ax1.tick_params(axis='y', labelcolor=color)

color = 'tab:green'
trainline, = ax1.plot(t, model.stats().train_acc, color=color)
ax1.legend((trainline, testline), ('Train', 'Test'), loc=7)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('learning rate', color=color)  # we already handled the x-label with ax1
lrline, = ax2.plot(t, model.stats().lr, color=color)
ax2.legend((lrline, ), ('LR',), loc=8)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Learning Rate and Train/test Accuracy Comparison")
plt.show()
