# %% [markdown]
# <a href="https://colab.research.google.com/github/DrVenkataRajeshKumar/S11/blob/master/S11trail2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from torchvision import datasets
train = datasets.CIFAR10('./data', train=True, download=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
# !pip install -U git+https://github.com/albu/albumentations > /dev/null && echo "All libraries are successfully installed!"
# Out:
#   Running command git clone -q https://github.com/albu/albumentations /tmp/pip-req-build-2_vd_b9u
# All libraries are successfully installed!

# %%
from tqdm import tqdm_notebook
from PIL import Image
import numpy as np
n = 0
s = np.zeros(3)
sq = np.zeros(3)
for data, l in tqdm_notebook(train):
  x = np.array(data)/255
  s += x.sum(axis=(0,1))
  sq += np.sum(np.square(x), axis=(0,1))
  n += x.shape[0]*x.shape[1]

mu = s/n
std = np.sqrt((sq/n - np.square(mu)))
print(mu, sq/n, std, n)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))
# [0.49139968 0.48215841 0.44653091] [0.30249857 0.29176174 0.26781806] [0.24703223 0.24348513 0.26158784] 51200000

# %%
import sys
sys.path.append('/content/drive/My Drive/EVA4')

# %%
import numpy as np
from eva4albumentations import AlbumentationTransforms
import albumentations as A


channel_means = (0.49139968, 0.48215841, 0.44653091)
channel_stdevs = (0.24703223, 0.24348513, 0.26158784)
# Train Phase transformations
train_transforms = AlbumentationTransforms([
                                       A.PadIfNeeded(40,40),
                                       A.RandomCrop(32,32),
                                       A.HorizontalFlip(),
                                       A.Normalize(mean=channel_means, std=channel_stdevs),
                                       A.Cutout(8)
                                       ])

fillmeans = (np.array(channel_means)).astype(np.uint8)



# Test Phase transformations
test_transforms = AlbumentationTransforms([A.Normalize(mean=channel_means, std=channel_stdevs)])

# %%
from torchvision import datasets
train = datasets.CIFAR10('./data', train=True, download=True, transform=train_transforms)
test = datasets.CIFAR10('./data', train=False, download=True, transform=test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import eva4dataloaders

dataloader = eva4dataloaders.DataLoader()

# train dataloader
train_loader = dataloader.load(train)

# test dataloader
test_loader = dataloader.load(test)

# %%
import numpy as np
dataiter = iter(train_loader)
images, labels = dataiter.next()
i = images[90].numpy()
print(np.max(i), np.min(i))
# Out:
# 1.5826002 -1.9892128

# %%
from __future__ import print_function

def unnormalize(img):
  img = img.numpy().astype(dtype=np.float32)
  
  for i in range(img.shape[0]):
    img[i] = (img[i]*channel_stdevs[i])+channel_means[i]
  
  return np.transpose(img, (1,2,0))

# %matplotlib inline
import matplotlib.pyplot as plt
dataiter = iter(train_loader)
images, labels = dataiter.next()

print(images.shape)
print(labels.shape)

num_classes = 10
# display 10 images from each category. 
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
r, c = 10, 11
n = 5
fig = plt.figure(figsize=(10,10))
fig.subplots_adjust(hspace=0.01, wspace=0.01)
for i in range(num_classes):
    idx = np.random.choice(np.where(labels[:]==i)[0], n)
    ax = plt.subplot(r, c, i*c+1)
    ax.text(-1.5, 0.5, class_names[i], fontsize=14)
    plt.axis('off')
    for j in range(1, n+1):
      plt.subplot(r, c, i*c+j+1)
      plt.imshow(unnormalize(images[idx[j-1]]), interpolation='none')
      plt.axis('off')
plt.show()
# Out:
# torch.Size([512, 3, 32, 32])
# torch.Size([512])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import a11
import torch

model = a11.Quiz11()
use_cuda = torch.cuda.is_available()
model.device = torch.device("cuda" if use_cuda else "cpu")
model.to(model.device)
model.summary((3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#               ReLU-2           [-1, 64, 32, 32]               0
#        BatchNorm2d-3           [-1, 64, 32, 32]             128
#             Conv2d-4          [-1, 128, 32, 32]          73,728
#          MaxPool2d-5          [-1, 128, 16, 16]               0
#               ReLU-6          [-1, 128, 16, 16]               0
#        BatchNorm2d-7          [-1, 128, 16, 16]             256
#             Conv2d-8          [-1, 128, 16, 16]         147,456
#               ReLU-9          [-1, 128, 16, 16]               0
#       BatchNorm2d-10          [-1, 128, 16, 16]             256
#            Conv2d-11          [-1, 128, 16, 16]         147,456
#              ReLU-12          [-1, 128, 16, 16]               0
#       BatchNorm2d-13          [-1, 128, 16, 16]             256
#            Conv2d-14          [-1, 256, 16, 16]         294,912
#         MaxPool2d-15            [-1, 256, 8, 8]               0
#              ReLU-16            [-1, 256, 8, 8]               0
#       BatchNorm2d-17            [-1, 256, 8, 8]             512
#            Conv2d-18            [-1, 512, 8, 8]       1,179,648
#         MaxPool2d-19            [-1, 512, 4, 4]               0
#              ReLU-20            [-1, 512, 4, 4]               0
#       BatchNorm2d-21            [-1, 512, 4, 4]           1,024
#            Conv2d-22            [-1, 512, 4, 4]       2,359,296
#              ReLU-23            [-1, 512, 4, 4]               0
#       BatchNorm2d-24            [-1, 512, 4, 4]           1,024
#            Conv2d-25            [-1, 512, 4, 4]       2,359,296
#              ReLU-26            [-1, 512, 4, 4]               0
#       BatchNorm2d-27            [-1, 512, 4, 4]           1,024
#         MaxPool2d-28            [-1, 512, 1, 1]               0
#            Conv2d-29             [-1, 10, 1, 1]           5,130
# ================================================================
# Total params: 6,573,130
# Trainable params: 6,573,130
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 6.44
# Params size (MB): 25.07
# Estimated Total Size (MB): 31.53
# ----------------------------------------------------------------

# %%
def get_triangular_lr(iteration, stepsize, base_lr, max_lr):
    """Given the inputs, calculates the lr that should be applicable for this iteration"""
    cycle = np.floor(1 + iteration/(2  * stepsize))
    x = np.abs(iteration/stepsize - 2 * cycle + 1)
    lr = base_lr + (max_lr - base_lr) * np.maximum(0, (1-x))
    return lr


num_iterations = 500
stepsize = 50
base_lr = 0.001
max_lr = 0.01
lr_trend = list()

for iteration in range(num_iterations):
    lr = get_triangular_lr(iteration, stepsize, base_lr, max_lr)
    # Update your optimizer to use this learning rate in this iteration
    lr_trend.append(lr)

plt.plot(lr_trend)

# %%
# LR finder fast ai approach
from lrfinder import LRFinder
import torch.optim as optim
import torch.nn as nn
L1lambda = 0
L2lambda = 1e-4
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-7, momentum=0.9, nesterov=True, weight_decay=L2lambda)
lr_finder = LRFinder(model, optimizer, criterion, device=model.device)
lr_finder.range_test(train_loader, end_lr=100, num_iter=100)
lr_finder.plot() # to inspect the loss-learning rate graph
lr_finder.reset() # to reset the model and optimizer to their initial state
# Out:
# WARNING:lrfinder:To enable mixed precision training, please install `apex`. Or you can re-install this package by the following command:
#   pip install torch-lr-finder -v --global-option="amp"
# HBox(children=(IntProgress(value=0), HTML(value='')))
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau


EPOCHS = 25
#scheduler = StepLR(optimizer, step_size=5, gamma=0.5)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, nesterov=True, weight_decay=L2lambda)
scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer,
                 max_lr=0.03,
                 total_steps=25,
                 epochs=25,
                 pct_start=0.2,
                 cycle_momentum=False,
                 base_momentum=0.85,
                 max_momentum=0.95,
                 div_factor=10.,
                 final_div_factor=1e4,
                 last_epoch=-1)



model.gotrain(optimizer, train_loader, test_loader, EPOCHS, "/content/drive/My Drive", scheduler, False, L1lambda)
# Out:
# HBox(children=(IntProgress(value=0, description='Epochs', max=25, style=ProgressStyle(description_width='initi…
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (100000.000000 --> 1.200723).  Saving model ...
# Epoch: 1, Train set: Average loss: 0.0031, Accuracy: 43.77%; Test set: Average loss: 1.2007, Accuracy: 57.02%
# Learning Rate = 0.003000
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (1.200723 --> 1.131671).  Saving model ...
# Epoch: 2, Train set: Average loss: 0.0027, Accuracy: 54.04%; Test set: Average loss: 1.1317, Accuracy: 60.04%
# Learning Rate = 0.006954
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (1.131671 --> 0.953741).  Saving model ...
# Epoch: 3, Train set: Average loss: 0.0036, Accuracy: 48.98%; Test set: Average loss: 0.9537, Accuracy: 66.17%
# Learning Rate = 0.016500
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Epoch: 4, Train set: Average loss: 0.0024, Accuracy: 60.13%; Test set: Average loss: 1.0171, Accuracy: 65.16%
# Learning Rate = 0.026046
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.953741 --> 0.850270).  Saving model ...
# Epoch: 5, Train set: Average loss: 0.0020, Accuracy: 65.46%; Test set: Average loss: 0.8503, Accuracy: 71.79%
# Learning Rate = 0.030000
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.850270 --> 0.653238).  Saving model ...
# Epoch: 6, Train set: Average loss: 0.0016, Accuracy: 71.74%; Test set: Average loss: 0.6532, Accuracy: 77.54%
# Learning Rate = 0.029815
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.653238 --> 0.575675).  Saving model ...
# Epoch: 7, Train set: Average loss: 0.0014, Accuracy: 75.21%; Test set: Average loss: 0.5757, Accuracy: 80.94%
# Learning Rate = 0.029266
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.575675 --> 0.514781).  Saving model ...
# Epoch: 8, Train set: Average loss: 0.0013, Accuracy: 77.24%; Test set: Average loss: 0.5148, Accuracy: 82.43%
# Learning Rate = 0.028365
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Epoch: 9, Train set: Average loss: 0.0012, Accuracy: 79.29%; Test set: Average loss: 0.5254, Accuracy: 82.90%
# Learning Rate = 0.027135
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.514781 --> 0.465761).  Saving model ...
# Epoch: 10, Train set: Average loss: 0.0011, Accuracy: 80.61%; Test set: Average loss: 0.4658, Accuracy: 84.20%
# Learning Rate = 0.025607
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.465761 --> 0.451349).  Saving model ...
# Epoch: 11, Train set: Average loss: 0.0010, Accuracy: 82.32%; Test set: Average loss: 0.4513, Accuracy: 85.36%
# Learning Rate = 0.023817
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.451349 --> 0.429204).  Saving model ...
# Epoch: 12, Train set: Average loss: 0.0009, Accuracy: 83.43%; Test set: Average loss: 0.4292, Accuracy: 85.75%
# Learning Rate = 0.021810
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.429204 --> 0.398590).  Saving model ...
# Epoch: 13, Train set: Average loss: 0.0009, Accuracy: 84.24%; Test set: Average loss: 0.3986, Accuracy: 87.03%
# Learning Rate = 0.019635
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.398590 --> 0.395324).  Saving model ...
# Epoch: 14, Train set: Average loss: 0.0008, Accuracy: 85.56%; Test set: Average loss: 0.3953, Accuracy: 86.78%
# Learning Rate = 0.017347
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.395324 --> 0.353234).  Saving model ...
# Epoch: 15, Train set: Average loss: 0.0008, Accuracy: 86.27%; Test set: Average loss: 0.3532, Accuracy: 88.15%
# Learning Rate = 0.015000
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.353234 --> 0.336360).  Saving model ...
# Epoch: 16, Train set: Average loss: 0.0007, Accuracy: 87.31%; Test set: Average loss: 0.3364, Accuracy: 88.89%
# Learning Rate = 0.012654
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.336360 --> 0.332028).  Saving model ...
# Epoch: 17, Train set: Average loss: 0.0007, Accuracy: 88.19%; Test set: Average loss: 0.3320, Accuracy: 89.22%
# Learning Rate = 0.010365
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.332028 --> 0.323198).  Saving model ...
# Epoch: 18, Train set: Average loss: 0.0006, Accuracy: 88.94%; Test set: Average loss: 0.3232, Accuracy: 89.52%
# Learning Rate = 0.008190
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.323198 --> 0.312883).  Saving model ...
# Epoch: 19, Train set: Average loss: 0.0006, Accuracy: 89.44%; Test set: Average loss: 0.3129, Accuracy: 89.69%
# Learning Rate = 0.006183
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.312883 --> 0.305740).  Saving model ...
# Epoch: 20, Train set: Average loss: 0.0006, Accuracy: 89.91%; Test set: Average loss: 0.3057, Accuracy: 89.86%
# Learning Rate = 0.004394
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.305740 --> 0.298225).  Saving model ...
# Epoch: 21, Train set: Average loss: 0.0005, Accuracy: 90.40%; Test set: Average loss: 0.2982, Accuracy: 90.06%
# Learning Rate = 0.002865
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.298225 --> 0.295277).  Saving model ...
# Epoch: 22, Train set: Average loss: 0.0005, Accuracy: 90.68%; Test set: Average loss: 0.2953, Accuracy: 90.06%
# Learning Rate = 0.001635
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.295277 --> 0.292479).  Saving model ...
# Epoch: 23, Train set: Average loss: 0.0005, Accuracy: 91.05%; Test set: Average loss: 0.2925, Accuracy: 90.16%
# Learning Rate = 0.000734
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Validation loss decreased (0.292479 --> 0.290335).  Saving model ...
# Epoch: 24, Train set: Average loss: 0.0005, Accuracy: 91.17%; Test set: Average loss: 0.2903, Accuracy: 90.24%
# Learning Rate = 0.000185
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Epoch: 25, Train set: Average loss: 0.0005, Accuracy: 91.26%; Test set: Average loss: 0.2906, Accuracy: 90.31%
# Learning Rate = 0.000000

# %%
fig, ax1 = plt.subplots()
t = np.arange(1, 26)
color = 'tab:red'
ax1.set_xlabel('epoch (s)')
ax1.set_ylabel('accuracy', color=color)
testline, = ax1.plot(t, model.stats().test_acc, color=color)
ax1.tick_params(axis='y', labelcolor=color)

color = 'tab:green'
trainline, = ax1.plot(t, model.stats().train_acc, color=color)
ax1.legend((trainline, testline), ('Train', 'Test'), loc=7)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('learning rate', color=color)  # we already handled the x-label with ax1
lrline, = ax2.plot(t, model.stats().lr, color=color)
ax2.legend((lrline, ), ('LR',), loc=8)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Learning Rate and Train/test Accuracy Comparison")
plt.show()
